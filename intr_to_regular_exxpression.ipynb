# %% [markdown]
# This notebook is all about beginning to understand the idea of regular exxxxpresions!

# %%
import pandas as pd

# %%
df = pd.read_csv('data/stopwords.txt',header=None)
df.head()
# Out:
#            0
# 0        a's
# 1       able
# 2      about
# 3      above
# 4  according

# %%
words = list(df[0])

# %%
words
# Out:
# ["a's",
#  'able',
#  'about',
#  'above',
#  'according',
#  'accordingly',
#  'across',
#  'actually',
#  'after',
#  'afterwards',
#  'again',
#  'against',
#  "ain't",
#  'all',
#  'allow',
#  'allows',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'among',
#  'amongst',
#  'an',
#  'and',
#  'another',
#  'any',
#  'anybody',
#  'anyhow',
#  'anyone',
#  'anything',
#  'anyway',
#  'anyways',
#  'anywhere',
#  'apart',
#  'appear',
#  'appreciate',
#  'appropriate',
#  'are',
#  "aren't",
#  'around',
#  'as',
#  'aside',
#  'ask',
#  'asking',
#  'associated',
#  'at',
#  'available',
#  'away',
#  'awfully',
#  'be',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'becoming',
#  'been',
#  'before',
#  'beforehand',
#  'behind',
#  'being',
#  'believe',
#  'below',
#  'beside',
#  'besides',
#  'best',
#  'better',
#  'between',
#  'beyond',
#  'both',
#  'brief',
#  'but',
#  'by',
#  "c'mon",
#  "c's",
# ...

# %%
practice_string = '123 easY Street'

# %%
tweet = 'i freakin\' love ice cream it\'s the best!'

# %%
tweet
# Out:
# "i freakin' love ice cream it's the best!"

# %% [markdown]
# sentiment analysis. the idea of learning how someones experience was.
